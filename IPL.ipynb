# %% [markdown]
# <h1><center>EDA ON IPL DATASETS</h1>

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQU5aqla9UUqqqy85CjEm-mHMU6kChVdcI-4A&usqp=CAU" alt="alternatetext" style="width:500px;height:300px;">

# %% [markdown]
# <h2>CONTEXT</h2><br>
# Cricket is a bat-and-ball game played between two teams of eleven players each on a cricket field, at the centre of which is a rectangular 20-metre (22-yard) pitch with a target at each end called the wicket (a set of three wooden stumps upon which two bails sit). Each phase of play is called an innings, during which one team bats, attempting to score as many runs as possible, whilst their opponents bowl and field, attempting to minimise the number of runs scored. When each innings ends, the teams usually swap roles for the next innings (i.e. the team that previously batted will bowl/field, and vice versa). The teams each bat for one or two innings, depending on the type of match. The winning team is the one that scores the most runs, including any extras gained (except when the result is not a win/loss result). Source: <a href="https://en.wikipedia.org/wiki/Cricket">https://en.wikipedia.org/wiki/Cricket</a><br>
# <br>
# Indian Premier League (IPL) is a Twenty20 cricket format league in India. It is usually played in April and May every year. As of 2019, the title sponsor of the game is Vivo. The league was founded by Board of Control for Cricket India (BCCI) in 2008.

# %% [markdown]
# <h2>CONTENT</h2><br>
# <ul>
# <li>All Indian Premier League Cricket matches between 2008 and 2019.</li>
#
# <li>This is the ball by ball data of all the IPL cricket matches till season 11.</li>
#
# <li>The dataset contains 2 files: deliveries.csv and matches.csv.</li>
#
# <li>matches.csv contains details related to the match such as location, contesting teams, umpires, results, etc.</li>
#
# <li>deliveries.csv is the ball-by-ball data of all the IPL matches including data of the batting team, batsman, bowler, non-striker, runs scored, etc.</li>
# </ul>

# %%
#Importing required Libraries
import pandas as pd
import numpy as np

# %%
#Importing data
matches=pd.read_csv('C:/Users\Shubhangi\Desktop\programming\machine_learning\project\Datasets\matches.csv')

# %%
deliveries=pd.read_csv('C:/Users\Shubhangi\Desktop\programming\machine_learning\project\Datasets\deliveries.csv')

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deliveries.head(5)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
print("Shape of Match dataset:",matches.shape)
# Out:
# Shape of Match dataset: (756, 18)

# %%
print("Shape of Deliveries dataset:",deliveries.shape)
# Out:
# Shape of Deliveries dataset: (179078, 21)

# %%
#Let's see column names
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#Let's see column names
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#Seeing some basic information
print("Information about the dataset(Match):\n")
matches.info()
# Out:
# Information about the dataset(Match):
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
# ...

# %%
#Seeing some basic information
print("Information about the dataset(Deliveries):\n")
deliveries.info()
# Out:
# Information about the dataset(Deliveries):
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
# ...

# %%
print('Total No. of Seasons:',matches['season'].nunique())
# Out:
# Total No. of Seasons: 12

# %%
print('Seasons:\n',matches['season'].unique())
# Out:
# Seasons:
#  [2017 2008 2009 2010 2011 2012 2013 2014 2015 2016 2018 2019]

# %%
print('Total No. of Cities:',matches['city'].nunique())
# Out:
# Total No. of Cities: 32

# %%
print('City Names:\n',matches['city'].unique())
# Out:
# City Names:
#  ['Hyderabad' 'Pune' 'Rajkot' 'Indore' 'Bangalore' 'Mumbai' 'Kolkata'
#  'Delhi' 'Chandigarh' 'Kanpur' 'Jaipur' 'Chennai' 'Cape Town'
#  'Port Elizabeth' 'Durban' 'Centurion' 'East London' 'Johannesburg'
#  'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur' 'Dharamsala'
#  'Kochi' 'Visakhapatnam' 'Raipur' 'Ranchi' 'Abu Dhabi' 'Sharjah' nan
#  'Mohali' 'Bengaluru']

# %%
print('Total No. of Teams:',matches['team1'].nunique())
# Out:
# Total No. of Teams: 15

# %%
print('Teams:\n',matches['team1'].unique())
# Out:
# Teams:
#  ['Sunrisers Hyderabad' 'Mumbai Indians' 'Gujarat Lions'
#  'Rising Pune Supergiant' 'Royal Challengers Bangalore'
#  'Kolkata Knight Riders' 'Delhi Daredevils' 'Kings XI Punjab'
#  'Chennai Super Kings' 'Rajasthan Royals' 'Deccan Chargers'
#  'Kochi Tuskers Kerala' 'Pune Warriors' 'Rising Pune Supergiants'
#  'Delhi Capitals']

# %%
print('Total No. of Venue:',matches['venue'].nunique())
# Out:
# Total No. of Venue: 41

# %%
print('Venue:\n',matches['venue'].unique())
# Out:
# Venue:
#  ['Rajiv Gandhi International Stadium, Uppal'
#  'Maharashtra Cricket Association Stadium'
#  'Saurashtra Cricket Association Stadium' 'Holkar Cricket Stadium'
#  'M Chinnaswamy Stadium' 'Wankhede Stadium' 'Eden Gardens'
#  'Feroz Shah Kotla' 'Punjab Cricket Association IS Bindra Stadium, Mohali'
#  'Green Park' 'Punjab Cricket Association Stadium, Mohali'
#  'Sawai Mansingh Stadium' 'MA Chidambaram Stadium, Chepauk'
#  'Dr DY Patil Sports Academy' 'Newlands' "St George's Park" 'Kingsmead'
#  'SuperSport Park' 'Buffalo Park' 'New Wanderers Stadium'
#  'De Beers Diamond Oval' 'OUTsurance Oval' 'Brabourne Stadium'
#  'Sardar Patel Stadium, Motera' 'Barabati Stadium'
#  'Vidarbha Cricket Association Stadium, Jamtha'
#  'Himachal Pradesh Cricket Association Stadium' 'Nehru Stadium'
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium'
#  'Subrata Roy Sahara Stadium'
#  'Shaheed Veer Narayan Singh International Stadium'
# ...

# %%
print('No of players who won man of the match:',matches['player_of_match'].nunique())
# Out:
# No of players who won man of the match: 226

# %%
print('No of man of the matches won by players-\n')
matches['player_of_match'].value_counts()
# Out:
# No of man of the matches won by players-
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# MS Dhoni          17
# RG Sharma         17
#                   ..
# LJ Wright          1
# Imran Tahir        1
# S Hetmyer          1
# RS Bopara          1
# RE Levi            1
# Name: player_of_match, Length: 226, dtype: int64

# %%
print('Players who won man of the match most no.of time(Top ten)-\n')
matches['player_of_match'].value_counts().head(10)
# Out:
# Players who won man of the match most no.of time(Top ten)-
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# MS Dhoni          17
# RG Sharma         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# Name: player_of_match, dtype: int64

# %%
#checking for null values
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
#Printing rows having nan values
matches[matches.isnull().any(axis=1)]
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 633    634    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 634    635    2016          Delhi  2016-05-27                Gujarat Lions
# 635    636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
# 744  11340    2019      Bengaluru    30/04/19  Royal Challengers Bangalore
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
#
# ...

# %%
#Total no of rows with atleast one null value
matches.isnull().any(axis = 1).sum()
# Out:
# 638

# %%
#Details about Umpires
u1=set(matches['umpire1'])
u2=set(matches['umpire2'])
u3=set(matches['umpire3'])

ump=u1.intersection(u2)
ump=ump.intersection(u3)
#Removing null values from set
ump.discard(np.nan)
#No of umpires in IPL
print("No. of Umpires",len(ump))
print("Umpire Names-\n",ump)
# Out:
# No. of Umpires 19
# Umpire Names-
#  {'Nitin Menon', 'O Nandan', 'S Ravi', 'Anil Chaudhary', 'Ulhas Gandhe', 'Bruce Oxenford', 'Ian Gould', 'Anil Dandekar', 'Vineet Kulkarni', 'C Shamshuddin', 'K Ananthapadmanabhan', 'Yeshwant Barde', 'Chris Gaffaney', 'KN Ananthapadmanabhan', 'A Nanda Kishore', 'Rod Tucker', 'Nanda Kishore', 'Kumar Dharmasena', 'Nigel Llong'}

# %%
#Different types of toss decisions
matches['toss_decision'].value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
matches['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
#Analyzing wins of teams using describe function
matches[['win_by_runs', 'win_by_wickets']].describe()

import matplotlib.pyplot as plt
plt.figure(figsize=(9,8))
matches[['win_by_runs', 'win_by_wickets']].describe().plot(kind = 'bar',color=['coral','lightgreen'])
plt.show()

# %%
#team who won by maximum runs
matches[matches['win_by_runs'] == 146][['season','team1', 'team2','winner','win_by_runs','player_of_match']]
# Out:
#     season           team1             team2          winner  win_by_runs  \
# 43    2017  Mumbai Indians  Delhi Daredevils  Mumbai Indians          146
#
#    player_of_match
# 43     LMP Simmons

# %%
# lets also check the Teams who lost the Match by all the 10 Wickets
matches[matches['win_by_wickets']==10][['season','team1', 'team2','winner','win_by_wickets','player_of_match']]
# Out:
#      season             team1                        team2  \
# 2      2017     Gujarat Lions        Kolkata Knight Riders
# 34     2017  Delhi Daredevils              Kings XI Punjab
# 71     2008    Mumbai Indians              Deccan Chargers
# 119    2009   Kings XI Punjab             Delhi Daredevils
# 183    2010  Rajasthan Royals  Royal Challengers Bangalore
# 298    2011    Mumbai Indians             Rajasthan Royals
# 376    2012  Rajasthan Royals               Mumbai Indians
# 390    2013   Kings XI Punjab          Chennai Super Kings
# 542    2015  Delhi Daredevils  Royal Challengers Bangalore
# 590    2016     Gujarat Lions          Sunrisers Hyderabad
# 683    2018   Kings XI Punjab  Royal Challengers Bangalore
#
#                           winner  win_by_wickets player_of_match
# 2          Kolkata Knight Riders              10         CA Lynn
# 34               Kings XI Punjab              10  Sandeep Sharma
# ...

# %%
#No of Teams who won by 10 wickets
len(matches[matches['win_by_wickets']==10][['season','team1', 'team2','winner','win_by_wickets','player_of_match']])
# Out:
# 11

# %%
#Tie and no result matches
matches[(matches['result']=='tie')|(matches['result']=='no result')][['date','team1','team2', 'result', 'winner']]
# Out:
#            date                        team1                        team2  \
# 33   2017-04-29                Gujarat Lions               Mumbai Indians
# 125  2009-04-23             Rajasthan Royals        Kolkata Knight Riders
# 189  2010-03-21              Kings XI Punjab          Chennai Super Kings
# 300  2011-05-21             Delhi Daredevils                Pune Warriors
# 387  2013-04-07  Royal Challengers Bangalore          Sunrisers Hyderabad
# 400  2013-04-16             Delhi Daredevils  Royal Challengers Bangalore
# 475  2014-04-29             Rajasthan Royals        Kolkata Knight Riders
# 535  2015-04-21             Rajasthan Royals              Kings XI Punjab
# 545  2015-04-29  Royal Challengers Bangalore             Rajasthan Royals
# 570  2015-05-17             Delhi Daredevils  Royal Challengers Bangalore
# 705    30/03/19        Kolkata Knight Riders               Delhi Capitals
# 744    30/04/19  Royal Challengers Bangalore             Rajasthan Royals
# ...

# %%
# lets check the Number matches in each Season
import seaborn as sns
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12, 5)
sns.countplot(x = matches['season'].sort_values(), palette = 'rainbow')
plt.title('Number matches in each Season', fontsize = 20)
plt.show()

# %%
#Each Teams's matches count
teams_matches1=pd.DataFrame(matches['team1'].value_counts())
teams_matches2=pd.DataFrame(matches['team2'].value_counts())
team_matches=pd.DataFrame(pd.concat([teams_matches1, teams_matches2], axis=1).sum(axis=1)).reset_index()
plt.rcParams['figure.figsize']=15,7
sns.barplot(y=team_matches['index'], x=team_matches[0], palette = 'viridis')
plt.title('Each teams\' matches count', fontsize = 25)
plt.xlabel('count', fontsize = 20)
plt.ylabel('teams', fontsize = 20)
plt.show()

# %%
#Most matches played venues
sns.barplot(y=matches['venue'].value_counts().head(10).index, x=matches['venue'].value_counts().head(10).values, palette = 'coolwarm')
plt.title('most matches played venues', fontsize=25)
plt.xlabel('count', fontsize=20)
plt.ylabel('venues',fontsize=20)
plt.show()

# %%
# lets compare the Toss Decisions

sns.countplot(matches['season'].sort_values(), hue = matches['toss_decision'], palette = 'spring')
plt.title("Decision to field or bat across seasons", fontsize = 20)
plt.xlabel(" ")
plt.ylabel(" ")
plt.show()
# Out:
# C:\Users\Shubhangi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Plot different type of results
sns.countplot(matches['season'].sort_values(), hue = matches['result'], palette = 'plasma')
plt.title("Decision to field or bat across seasons", fontsize = 20)
plt.xlabel(" ")
plt.ylabel(" ")
plt.show()
# Out:
# C:\Users\Shubhangi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Cities and no.of matches played in a particular season 
def match_city(season):#Creating function
    a=matches[(matches['season']==season)]
    a=pd.DataFrame(a['city'].value_counts())
    return a.style.background_gradient(cmap='Set2')

# %%
#Calling the function
match_city(2010)
# Out:
# <style  type="text/css" >
# #T_3a7ba905_6616_11eb_a44b_30e37a987848row0_col0{
#             background-color:  #b3b3b3;
#             color:  #000000;
#         }#T_3a7ba905_6616_11eb_a44b_30e37a987848row1_col0,#T_3a7ba905_6616_11eb_a44b_30e37a987848row2_col0,#T_3a7ba905_6616_11eb_a44b_30e37a987848row3_col0,#T_3a7ba905_6616_11eb_a44b_30e37a987848row4_col0{
#             background-color:  #e78ac3;
#             color:  #000000;
#         }#T_3a7ba905_6616_11eb_a44b_30e37a987848row5_col0{
#             background-color:  #8da0cb;
#             color:  #000000;
#         }#T_3a7ba905_6616_11eb_a44b_30e37a987848row6_col0{
#             background-color:  #fc8d62;
#             color:  #000000;
#         }#T_3a7ba905_6616_11eb_a44b_30e37a987848row7_col0,#T_3a7ba905_6616_11eb_a44b_30e37a987848row8_col0,#T_3a7ba905_6616_11eb_a44b_30e37a987848row9_col0,#T_3a7ba905_6616_11eb_a44b_30e37a987848row10_col0{
#             background-color:  #66c2a5;
#             color:  #000000;
# ...

# %%
#Top 10 cities where maximum no of matches has been played
top10cities=matches["city"].value_counts()[:10]
plt.figure(figsize=(12,12))
sns.barplot(top10cities,top10cities.index)
# Out:
# C:\Users\Shubhangi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='city'>

# %%
matches.loc[matches["venue"]=="Wankhede Stadium",["venue","win_by_runs","win_by_wickets"]]
# Out:
#                 venue  win_by_runs  win_by_wickets
# 6    Wankhede Stadium            0               4
# 9    Wankhede Stadium            0               4
# 15   Wankhede Stadium            0               6
# 23   Wankhede Stadium           14               0
# 27   Wankhede Stadium            3               0
# ..                ...          ...             ...
# 719  Wankhede Stadium            0               3
# 722  Wankhede Stadium            0               4
# 726  Wankhede Stadium            0               5
# 746  Wankhede Stadium            0               0
# 751  Wankhede Stadium            0               9
#
# [73 rows x 3 columns]

# %% [markdown]
# <h3>FINDING OUT STADIUM WISE MOST "WIN BY RUNS" AND "WIN BY WICKETS"</h3>

# %%
max_win_by_runs_by_venue = []
eachvenue = matches["venue"].unique()
for i in eachvenue :
    temp_each_venue = matches.loc[matches["venue"]==i,["venue","win_by_runs"]]
    temp_max_win_by_runs_by_venue = temp_each_venue["win_by_runs"].max()
    max_win_by_runs_by_venue.append(temp_max_win_by_runs_by_venue)
max_win_by_runs_by_venue
# Out:
# [77,
#  97,
#  26,
#  31,
#  144,
#  105,
#  102,
#  146,
#  26,
#  0,
#  76,
#  87,
#  97,
#  41,
#  75,
#  92,
#  78,
#  38,
#  78,
#  18,
#  53,
#  14,
#  63,
#  62,
#  44,
#  13,
#  111,
#  55,
#  85,
#  46,
#  15,
#  34,
#  93,
#  72,
#  15,
#  80,
#  40,
#  17,
#  118,
#  14,
#  0]

# %%
len(max_win_by_runs_by_venue)
# Out:
# 41

# %%
df_max_win_by_runs_by_venue = pd.DataFrame({"venue" : eachvenue,"max win by runs" : max_win_by_runs_by_venue}, columns = ["venue", "max win by runs"]).set_index("venue")
df_max_win_by_runs_by_venue
# Out:
#                                                     max win by runs
# venue
# Rajiv Gandhi International Stadium, Uppal                        77
# Maharashtra Cricket Association Stadium                          97
# Saurashtra Cricket Association Stadium                           26
# Holkar Cricket Stadium                                           31
# M Chinnaswamy Stadium                                           144
# Wankhede Stadium                                                105
# Eden Gardens                                                    102
# Feroz Shah Kotla                                                146
# Punjab Cricket Association IS Bindra Stadium, M...               26
# Green Park                                                        0
# Punjab Cricket Association Stadium, Mohali                       76
# Sawai Mansingh Stadium                                           87
# MA Chidambaram Stadium, Chepauk                                  97
# ...

# %%
max_win_by_wickets_by_venue = []
eachvenue = matches["venue"].unique()
for i in eachvenue :
    temp_each_venue = matches.loc[matches["venue"]==i,["venue","win_by_wickets"]]
    temp_max_win_by_wickets_by_venue = temp_each_venue["win_by_wickets"].max()
    max_win_by_wickets_by_venue.append(temp_max_win_by_wickets_by_venue)
max_win_by_wickets_by_venue
# Out:
# [9,
#  9,
#  10,
#  10,
#  10,
#  10,
#  9,
#  10,
#  10,
#  8,
#  10,
#  10,
#  9,
#  10,
#  10,
#  7,
#  9,
#  8,
#  7,
#  9,
#  7,
#  6,
#  7,
#  9,
#  9,
#  6,
#  6,
#  7,
#  7,
#  8,
#  7,
#  6,
#  6,
#  8,
#  7,
#  7,
#  6,
#  5,
#  9,
#  8,
#  6]

# %%
df_max_win_by_wickets_by_venue = pd.DataFrame({"venue" : eachvenue,"max win by wickets" : max_win_by_wickets_by_venue}, columns = ["venue", "max win by wickets"]).set_index("venue")
df_max_win_by_wickets_by_venue
# Out:
#                                                     max win by wickets
# venue
# Rajiv Gandhi International Stadium, Uppal                            9
# Maharashtra Cricket Association Stadium                              9
# Saurashtra Cricket Association Stadium                              10
# Holkar Cricket Stadium                                              10
# M Chinnaswamy Stadium                                               10
# Wankhede Stadium                                                    10
# Eden Gardens                                                         9
# Feroz Shah Kotla                                                    10
# Punjab Cricket Association IS Bindra Stadium, M...                  10
# Green Park                                                           8
# Punjab Cricket Association Stadium, Mohali                          10
# Sawai Mansingh Stadium                                              10
# ...

# %%
combined_each_venue = pd.merge(df_max_win_by_runs_by_venue,df_max_win_by_wickets_by_venue,left_index=True, right_index=True)
combined_each_venue
# Out:
#                                                     max win by runs  \
# venue
# Rajiv Gandhi International Stadium, Uppal                        77
# Maharashtra Cricket Association Stadium                          97
# Saurashtra Cricket Association Stadium                           26
# Holkar Cricket Stadium                                           31
# M Chinnaswamy Stadium                                           144
# Wankhede Stadium                                                105
# Eden Gardens                                                    102
# Feroz Shah Kotla                                                146
# Punjab Cricket Association IS Bindra Stadium, M...               26
# Green Park                                                        0
# Punjab Cricket Association Stadium, Mohali                       76
# Sawai Mansingh Stadium                                           87
# MA Chidambaram Stadium, Chepauk                                  97
# ...

# %%
sorted_combined_each_venue_by_runs = combined_each_venue.sort_values(by="max win by runs", ascending=False)
plt.figure(figsize=(14,14))
sns.barplot(sorted_combined_each_venue_by_runs["max win by runs"],sorted_combined_each_venue_by_runs.index, palette="rocket")
# Out:
# C:\Users\Shubhangi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='max win by runs', ylabel='venue'>

# %%
teams = matches["team1"].unique()
teams
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %% [markdown]
# <h3>FINDING OUT TOTAL RUNS SCORED BY EACH TEAM IN IPL</h3>

# %%
totalrunsofeachteamarr = []
for i in teams :
    temp = deliveries.loc[(deliveries["batting_team"] == i),["batting_team","total_runs"]]
    #tempruns=temp["batting_team"].value_counts().values
    tempruns = temp["total_runs"].sum()
    totalrunsofeachteamarr.append(tempruns)
totalrunsofeachteamarr
# Out:
# [17059,
#  29809,
#  4862,
#  2470,
#  28126,
#  27419,
#  24388,
#  27893,
#  26418,
#  22431,
#  11463,
#  1901,
#  6358,
#  2063,
#  2630]

# %%
totalrunsofeachteam = pd.DataFrame({"Team" : teams,"Total runs of each team" : totalrunsofeachteamarr}, columns = ["Team", "Total runs of each team"]).set_index("Team")
totalrunsofeachteam.sort_values(by="Total runs of each team", ascending=False,inplace = True)
totalrunsofeachteam
# Out:
#                              Total runs of each team
# Team
# Mumbai Indians                                 29809
# Royal Challengers Bangalore                    28126
# Kings XI Punjab                                27893
# Kolkata Knight Riders                          27419
# Chennai Super Kings                            26418
# Delhi Daredevils                               24388
# Rajasthan Royals                               22431
# Sunrisers Hyderabad                            17059
# Deccan Chargers                                11463
# Pune Warriors                                   6358
# Gujarat Lions                                   4862
# Delhi Capitals                                  2630
# Rising Pune Supergiant                          2470
# Rising Pune Supergiants                         2063
# Kochi Tuskers Kerala                            1901

# %%
plt.figure(figsize=(14,14))
sns.barplot(totalrunsofeachteam["Total runs of each team"],totalrunsofeachteam.index, palette ="deep")
# Out:
# C:\Users\Shubhangi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total runs of each team', ylabel='Team'>

# %% [markdown]
# <h3>Total Runs Of each batsman</h3>

# %%
batsman = deliveries["batsman"].unique()
batsman
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting', 'CH Gayle', 'Mandeep Singh', 'TM Head',
#        'KM Jadhav', 'SR Watson', 'Sachin Baby', 'STR Binny', 'S Aravind',
#        'YS Chahal', 'TS Mills', 'A Choudhary', 'PA Patel', 'JC Buttler',
#        'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard',
#        'HH Pandya', 'TG Southee', 'AM Rahane', 'MA Agarwal', 'SPD Smith',
#        'BA Stokes', 'MS Dhoni', 'JJ Roy', 'BB McCullum', 'SK Raina',
#        'AJ Finch', 'KD Karthik', 'G Gambhir', 'CA Lynn', 'MK Tiwary',
#        'DT Christian', 'HM Amla', 'M Vohra', 'WP Saha', 'AR Patel',
#        'GJ Maxwell', 'DA Miller', 'Vishnu Vinod', 'Iqbal Abdulla',
#        'P Negi', 'AP Tare', 'SW Billings', 'KK Nair', 'SV Samson',
#        'RR Pant', 'CH Morris', 'CR Brathwaite', 'PJ Cummins', 'A Mishra',
#        'S Nadeem', 'Z Khan', 'DR Smith', 'DS Kulkarni', 'P Kumar',
# ...

# %%
totalrunseachbatsmanarr = []
for i in batsman :
    temp1 = deliveries.loc[deliveries["batsman"]==i,["batsman","batsman_runs"]]
    temp2 = temp1["batsman_runs"].sum()
    totalrunseachbatsmanarr.append(temp2)
totalrunseachbatsmanarr
# Out:
# [4741,
#  4632,
#  969,
#  2765,
#  535,
#  240,
#  4560,
#  1547,
#  205,
#  1091,
#  3614,
#  137,
#  882,
#  59,
#  22,
#  8,
#  25,
#  2874,
#  1431,
#  4914,
#  1104,
#  3326,
#  915,
#  2784,
#  1118,
#  115,
#  3850,
#  1276,
#  2047,
#  647,
#  4477,
#  186,
#  2893,
#  5415,
#  1744,
#  3688,
#  4223,
#  1308,
#  1697,
#  448,
#  577,
#  1016,
#  1780,
#  806,
#  1403,
#  1875,
#  19,
#  88,
#  366,
#  339,
#  338,
#  1470,
#  2235,
#  1792,
#  520,
#  188,
#  77,
#  368,
#  32,
#  117,
#  2385,
#  101,
#  340,
#  32,
#  4446,
#  2872,
#  3241,
#  608,
#  63,
#  803,
#  834,
#  4428,
#  538,
#  1874,
#  771,
#  342,
#  73,
#  5,
#  26,
#  20,
#  1555,
#  574,
#  109,
#  190,
#  482,
#  124,
#  49,
#  5434,
#  91,
#  164,
#  36,
#  15,
#  1,
#  313,
#  187,
#  1714,
#  854,
#  24,
#  26,
#  711,
#  55,
#  7,
#  13,
#  724,
#  54,
#  146,
#  55,
#  1951,
#  94,
#  1319,
#  2489,
#  759,
#  527,
#  168,
#  70,
#  91,
#  52,
#  46,
#  127,
#  79,
#  317,
#  6,
#  12,
#  38,
# ...

# %%
totalrunseachbatsman = pd.DataFrame({"Batsman" : batsman,"Total runs by each Batsman" : totalrunseachbatsmanarr}, columns = ["Batsman", "Total runs by each Batsman"]).set_index("Batsman")
totalrunseachbatsman.sort_values(by="Total runs by each Batsman", ascending = False,inplace=True)
top25batsmanruns = totalrunseachbatsman["Total runs by each Batsman"].nlargest(25)
top25batsmanruns
# Out:
# Batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# AM Rahane         3850
# KD Karthik        3688
# SR Watson         3614
# AT Rayudu         3326
# YK Pathan         3241
# BB McCullum       2893
# PA Patel          2874
# MK Pandey         2872
# KA Pollard        2784
# Yuvraj Singh      2765
# V Sehwag          2728
# M Vijay           2590
# SE Marsh          2489
# JH Kallis         2427
# DR Smith          2385
# Name: Total runs by each Batsman, dtype: int64

# %%
#Top 25 Batsman with maximum runs
plt.figure(figsize=(12,12))
sns.barplot(top25batsmanruns,top25batsmanruns.index, palette ="Blues_r")
plt.tight_layout()
# Out:
# C:\Users\Shubhangi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <h3>Top 5 batsman with maximum sixies</h3>

# %%
sixescountarr = []
for i in batsman :
    temp3 = deliveries.loc[(deliveries["batsman"] == i) & (deliveries["batsman_runs"]==6),:].shape[0]
    sixescountarr.append(temp3)
sixescount = pd.DataFrame({"Batsman" : batsman,"Total sixes" : sixescountarr}, columns = ["Batsman", "Total sixes"]).set_index("Batsman")
sixescount = sixescount.sort_values(by="Total sixes", ascending = False)
sixescount = sixescount["Total sixes"].nlargest(5)
sixescount
# Out:
# Batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
# Name: Total sixes, dtype: int64

# %%
plt.figure()
sns.barplot(sixescount,sixescount.index, palette ="hls", orient="h")
plt.tight_layout()
# Out:
# C:\Users\Shubhangi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
